# %% [markdown]
# ### 导入库

# %%
from pyecharts import options as opts
from pyecharts.charts import Line
from pyecharts.faker import Faker
from pyecharts.commons.utils import JsCode
from pyecharts.globals import ThemeType, ChartType

import pandas as pd
import numpy as np

# %% [markdown]
# ### 基本作图
#
# 通过一个简单的例子来介绍如何最基本的折线图
#
# - 导入Line()
# - 导入x/y轴的数据
# - 全局设置项

# %%
c = (
    Line()
    .add_xaxis(['语文','数学','英语','体育'])   # 指定x/y轴数据
    .add_yaxis("张三",[68,75,83,100], is_step=True)   # is_step=True 表示呈梯状显示数据 
    .add_yaxis("李四",[82,98,78,82])
    .set_global_opts(title_opts=opts.TitleOpts(title="Line-基本示例"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="87b1bbf9d8904c54bf7952e59365b356" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_87b1bbf9d8904c54bf7952e59365b356 = echarts.init(
#                     document.getElementById('87b1bbf9d8904c54bf7952e59365b356'), 'white', {renderer: 'canvas'});
#                 var option_87b1bbf9d8904c54bf7952e59365b356 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5f20\u4e09",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": true,
#             "data": [
#                 [
#                     "\u8bed\u6587",
#                     68
#                 ],
#                 [
#                     "\u6570\u5b66",
#                     75
#                 ],
#                 [
#                     "\u82f1\u8bed",
#                     83
#                 ],
#                 [
#                     "\u4f53\u80b2",
#                     100
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u674e\u56db",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u8bed\u6587",
#                     82
#                 ],
#                 [
#                     "\u6570\u5b66",
#                     98
#                 ],
#                 [
#                     "\u82f1\u8bed",
#                     78
#                 ],
#                 [
#                     "\u4f53\u80b2",
#                     82
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5f20\u4e09",
#                 "\u674e\u56db"
#             ],
#             "selected": {
#                 "\u5f20\u4e09": true,
#                 "\u674e\u56db": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8bed\u6587",
#                 "\u6570\u5b66",
#                 "\u82f1\u8bed",
#                 "\u4f53\u80b2"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Line-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_87b1bbf9d8904c54bf7952e59365b356.setOption(option_87b1bbf9d8904c54bf7952e59365b356);
#         });
#     </script>

# %% [markdown]
# ### 面积图

# %%
data_x = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
data_y = [820, 932, 901, 934, 1290, 1330, 1320]


c = (
    Line()
    .add_xaxis(xaxis_data=data_x)  # 加入x轴数据
    .add_yaxis(
        series_name="面积图的制作",   # 图的名称
        y_axis=data_y,  # 加入y轴数据
        symbol="emptyCircle",  # 设置每个数据的符号标志
        is_symbol_show=True,  # 显示符号标志
        label_opts=opts.LabelOpts(is_show=False),
        areastyle_opts=opts.AreaStyleOpts(opacity=1, color="#B07570"),  # 设置透明度和标签
    )
    .set_global_opts(
        tooltip_opts=opts.TooltipOpts(is_show=False),
        yaxis_opts=opts.AxisOpts(
            type_="value",
            axistick_opts=opts.AxisTickOpts(is_show=True),
            splitline_opts=opts.SplitLineOpts(is_show=True),
        ),
        # boundary_gap 放在最后一个配置项, 不然会被覆盖
        xaxis_opts=opts.AxisOpts(type_="category", boundary_gap=False), # 保持图形从x=0开始，否则会出现间隙 
    )
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="94e531f08c31438bb1470978bd12695f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_94e531f08c31438bb1470978bd12695f = echarts.init(
#                     document.getElementById('94e531f08c31438bb1470978bd12695f'), 'white', {renderer: 'canvas'});
#                 var option_94e531f08c31438bb1470978bd12695f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u9762\u79ef\u56fe\u7684\u5236\u4f5c",
#             "connectNulls": false,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "Mon",
#                     820
#                 ],
#                 [
#                     "Tue",
#                     932
#                 ],
#                 [
#                     "Wed",
#                     901
#                 ],
#                 [
#                     "Thu",
#                     934
#                 ],
#                 [
#                     "Fri",
#                     1290
#                 ],
#                 [
#                     "Sat",
#                     1330
#                 ],
#                 [
#                     "Sun",
#                     1320
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 1,
#                 "color": "#B07570"
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9762\u79ef\u56fe\u7684\u5236\u4f5c"
#             ],
#             "selected": {
#                 "\u9762\u79ef\u56fe\u7684\u5236\u4f5c": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": false,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": false,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Mon",
#                 "Tue",
#                 "Wed",
#                 "Thu",
#                 "Fri",
#                 "Sat",
#                 "Sun"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_94e531f08c31438bb1470978bd12695f.setOption(option_94e531f08c31438bb1470978bd12695f);
#         });
#     </script>

# %%
### 面积图（左边存在间隙）

# %%
import pyecharts.options as opts
from pyecharts.charts import Line
from pyecharts.faker import Faker

c = (
    Line()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values(), areastyle_opts=opts.AreaStyleOpts(opacity=0.7))
    .add_yaxis("商家B", Faker.values(), areastyle_opts=opts.AreaStyleOpts(opacity=0.3))
    .set_global_opts(title_opts=opts.TitleOpts(title="Line-面积图"),
#                      xaxis_opts=opts.AxisOpts(type_="category", boundary_gap=False), # 从x=0开始，否则?会出现间隙 
                    )
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8f0a5322338c4e9da353df93ea203dfa" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8f0a5322338c4e9da353df93ea203dfa = echarts.init(
#                     document.getElementById('8f0a5322338c4e9da353df93ea203dfa'), 'white', {renderer: 'canvas'});
#                 var option_8f0a5322338c4e9da353df93ea203dfa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     31
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     96
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     97
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     58
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     32
#                 ],
#                 [
#                     "VIVO",
#                     73
#                 ],
#                 [
#                     "OPPO",
#                     58
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.7
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     61
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     20
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     139
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     43
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     136
#                 ],
#                 [
#                     "VIVO",
#                     85
#                 ],
#                 [
#                     "OPPO",
#                     25
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.3
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Line-\u9762\u79ef\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_8f0a5322338c4e9da353df93ea203dfa.setOption(option_8f0a5322338c4e9da353df93ea203dfa);
#         });
#     </script>

# %% [markdown]
# ### 制作面积图（紧贴y轴）
#
# 利用pyecharts制作面积图，紧贴y轴的样例

# %%
c = (
    Line()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values(), is_smooth=True)  # 对两个商家进行对比
    .add_yaxis("商家B", Faker.values(), is_smooth=True)  #  is_smooth表示用圆滑的曲线，而不是纯折线
    .set_series_opts(
        areastyle_opts=opts.AreaStyleOpts(opacity=0.5),
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Line-面积图（紧贴Y轴）"),
        xaxis_opts=opts.AxisOpts(
            axistick_opts=opts.AxisTickOpts(is_align_with_label=True),
            is_scale=False,
            boundary_gap=False,
        ),
    )
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="60ede2389a264358a0fb155c1b104278" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_60ede2389a264358a0fb155c1b104278 = echarts.init(
#                     document.getElementById('60ede2389a264358a0fb155c1b104278'), 'white', {renderer: 'canvas'});
#                 var option_60ede2389a264358a0fb155c1b104278 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     129
#                 ],
#                 [
#                     "\u6bdb\u8863",
#                     122
#                 ],
#                 [
#                     "\u9886\u5e26",
#                     66
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     102
#                 ],
#                 [
#                     "\u98ce\u8863",
#                     58
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     108
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     129
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.5
#             },
#             "zlevel": 0,
#             "z": 0,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     46
#                 ],
#                 [
#                     "\u6bdb\u8863",
#                     88
#                 ],
#                 [
#                     "\u9886\u5e26",
#                     61
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     41
#                 ],
#                 [
#                     "\u98ce\u8863",
#                     114
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     121
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     79
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.5
#             },
#             "zlevel": 0,
#             "z": 0,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": true,
#                 "inside": false
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": false,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Line-\u9762\u79ef\u56fe\uff08\u7d27\u8d34Y\u8f74\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_60ede2389a264358a0fb155c1b104278.setOption(option_60ede2389a264358a0fb155c1b104278);
#         });
#     </script>

# %%
Faker.choose()
# Out:
# ['可乐', '雪碧', '橙汁', '绿茶', '奶茶', '百威', '青岛']

# %%
Faker.values()
# Out:
# [134, 70, 84, 88, 25, 96, 117]

# %% [markdown]
# ###  空值处理
#
# 如果某组数据中出现了空值，如何处理？

# %%
y = Faker.values()
y[3], y[5] = None, None  # 将第3个和第5个数据指定为None
c = (
    Line()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", y, is_connect_nones=True)   # 在这里进行设置
    .set_global_opts(title_opts=opts.TitleOpts(title="Line-连接空数据"))
#     .render("line_connect_null.html")
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b185a40b4fde430d85cae14e667885ad" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b185a40b4fde430d85cae14e667885ad = echarts.init(
#                     document.getElementById('b185a40b4fde430d85cae14e667885ad'), 'white', {renderer: 'canvas'});
#                 var option_b185a40b4fde430d85cae14e667885ad = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": true,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     92
#                 ],
#                 [
#                     "\u6bdb\u8863",
#                     57
#                 ],
#                 [
#                     "\u9886\u5e26",
#                     34
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     null
#                 ],
#                 [
#                     "\u98ce\u8863",
#                     87
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     null
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     46
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Line-\u8fde\u63a5\u7a7a\u6570\u636e",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_b185a40b4fde430d85cae14e667885ad.setOption(option_b185a40b4fde430d85cae14e667885ad);
#         });
#     </script>

# %% [markdown]
# ### 堆叠折线图
#
# 将多条折线图绘制在一张图中

# %%
x_data = ["周一", "周二", "周三", "周四", "周五", "周六", "周日"]
y_data = [820, 932, 901, 934, 1290, 1330, 1320]


c = (
    Line()
    .add_xaxis(xaxis_data=x_data)  # 指定x轴数据
    
    # 添加多条y轴数据
    .add_yaxis(
        series_name="邮件营销",
        stack="总量",
        y_axis=[120, 132, 101, 134, 90, 230, 210],
        label_opts=opts.LabelOpts(is_show=False),
    )
    .add_yaxis(
        series_name="联盟广告",
        stack="总量",
        y_axis=[220, 182, 191, 234, 290, 330, 310],
        label_opts=opts.LabelOpts(is_show=False),
    )
    .add_yaxis(
        series_name="视频广告",
        stack="总量",
        y_axis=[150, 232, 201, 154, 190, 330, 410],
        label_opts=opts.LabelOpts(is_show=False),
    )
    .add_yaxis(
        series_name="直接访问",
        stack="总量",
        y_axis=[320, 332, 301, 334, 390, 330, 320],
        label_opts=opts.LabelOpts(is_show=False),
    )
    .add_yaxis(
        series_name="搜索引擎",
        stack="总量",
        y_axis=[820, 932, 901, 934, 1290, 1330, 1320],
        label_opts=opts.LabelOpts(is_show=False),
    )
    
    .set_global_opts(
        title_opts=opts.TitleOpts(title="堆叠折线图"),
        tooltip_opts=opts.TooltipOpts(trigger="axis"),
        yaxis_opts=opts.AxisOpts(
            type_="value",
            axistick_opts=opts.AxisTickOpts(is_show=True),
            splitline_opts=opts.SplitLineOpts(is_show=True),
        ),
        xaxis_opts=opts.AxisOpts(type_="category", boundary_gap=False),
    )
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e79ed03a035849af81dec9d53e2b0435" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e79ed03a035849af81dec9d53e2b0435 = echarts.init(
#                     document.getElementById('e79ed03a035849af81dec9d53e2b0435'), 'white', {renderer: 'canvas'});
#                 var option_e79ed03a035849af81dec9d53e2b0435 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u90ae\u4ef6\u8425\u9500",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "stack": "\u603b\u91cf",
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     120
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     132
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     101
#                 ],
#                 [
#                     "\u5468\u56db",
#                     134
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     90
#                 ],
#                 [
#                     "\u5468\u516d",
#                     230
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     210
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u8054\u76df\u5e7f\u544a",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "stack": "\u603b\u91cf",
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     220
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     182
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     191
#                 ],
#                 [
#                     "\u5468\u56db",
#                     234
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     290
#                 ],
#                 [
#                     "\u5468\u516d",
#                     330
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     310
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u89c6\u9891\u5e7f\u544a",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "stack": "\u603b\u91cf",
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     150
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     232
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     201
#                 ],
#                 [
#                     "\u5468\u56db",
#                     154
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     190
#                 ],
#                 [
#                     "\u5468\u516d",
#                     330
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     410
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u76f4\u63a5\u8bbf\u95ee",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "stack": "\u603b\u91cf",
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     320
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     332
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     301
#                 ],
#                 [
#                     "\u5468\u56db",
#                     334
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     390
#                 ],
#                 [
#                     "\u5468\u516d",
#                     330
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     320
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u641c\u7d22\u5f15\u64ce",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "stack": "\u603b\u91cf",
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     820
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     932
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     901
#                 ],
#                 [
#                     "\u5468\u56db",
#                     934
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     1290
#                 ],

# %% [markdown]
# ### 堆叠面积

# %%
import pyecharts.options as opts
from pyecharts.charts import Line


x_data = ["周一", "周二", "周三", "周四", "周五", "周六", "周日"]

c = (
    Line()
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="邮件营销",
        stack="总量",
        y_axis=[120, 132, 101, 134, 90, 230, 210],
        areastyle_opts=opts.AreaStyleOpts(opacity=0.5),
        label_opts=opts.LabelOpts(is_show=False),
    )
    .add_yaxis(
        series_name="联盟广告",
        stack="总量",
        y_axis=[220, 182, 191, 234, 290, 330, 310],
        areastyle_opts=opts.AreaStyleOpts(opacity=0.5),
        label_opts=opts.LabelOpts(is_show=False),
    )
    .add_yaxis(
        series_name="视频广告",
        stack="总量",
        y_axis=[150, 232, 201, 154, 190, 330, 410],
        areastyle_opts=opts.AreaStyleOpts(opacity=0.5),
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="堆叠区域图"),
        tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
        yaxis_opts=opts.AxisOpts(
            type_="value",
            axistick_opts=opts.AxisTickOpts(is_show=True),
            splitline_opts=opts.SplitLineOpts(is_show=True),
        ),
        xaxis_opts=opts.AxisOpts(type_="category", boundary_gap=False),
    )
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="abcf5eef0568454d80fa399f74f78d23" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_abcf5eef0568454d80fa399f74f78d23 = echarts.init(
#                     document.getElementById('abcf5eef0568454d80fa399f74f78d23'), 'white', {renderer: 'canvas'});
#                 var option_abcf5eef0568454d80fa399f74f78d23 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u90ae\u4ef6\u8425\u9500",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "stack": "\u603b\u91cf",
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     120
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     132
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     101
#                 ],
#                 [
#                     "\u5468\u56db",
#                     134
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     90
#                 ],
#                 [
#                     "\u5468\u516d",
#                     230
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     210
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.5
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u8054\u76df\u5e7f\u544a",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "stack": "\u603b\u91cf",
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     220
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     182
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     191
#                 ],
#                 [
#                     "\u5468\u56db",
#                     234
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     290
#                 ],
#                 [
#                     "\u5468\u516d",
#                     330
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     310
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.5
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u89c6\u9891\u5e7f\u544a",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "stack": "\u603b\u91cf",
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     150
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     232
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     201
#                 ],
#                 [
#                     "\u5468\u56db",
#                     154
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     190
#                 ],
#                 [
#                     "\u5468\u516d",
#                     330
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     410
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.5
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u90ae\u4ef6\u8425\u9500",
#                 "\u8054\u76df\u5e7f\u544a",
#                 "\u89c6\u9891\u5e7f\u544a"
#             ],
#             "selected": {
#                 "\u90ae\u4ef6\u8425\u9500": true,
#                 "\u8054\u76df\u5e7f\u544a": true,
#                 "\u89c6\u9891\u5e7f\u544a": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "axis",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "cross"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": false,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lin

# %% [markdown]
# ### 多个x轴

# %%
import pyecharts.options as opts
from pyecharts.charts import Line

from pyecharts.commons.utils import JsCode

# 如何使用JsCode
js_formatter = """function (params) {
        console.log(params);
        return '降水量  ' + params.value + (params.seriesData.length ? '：' + params.seriesData[0].data : '')
    }"""

c = (
    Line(init_opts=opts.InitOpts(width="1600px", height="800px"))
    .add_xaxis(
        xaxis_data=[
            "2016-1",
            "2016-2",
            "2016-3",
            "2016-4",
            "2016-5",
            "2016-6",
            "2016-7",
            "2016-8",
            "2016-9",
            "2016-10",
            "2016-11",
            "2016-12",
        ]
    )
    .extend_axis(
        xaxis_data=[
            "2015-1",
            "2015-2",
            "2015-3",
            "2015-4",
            "2015-5",
            "2015-6",
            "2015-7",
            "2015-8",
            "2015-9",
            "2015-10",
            "2015-11",
            "2015-12",
        ],
        xaxis=opts.AxisOpts(
            type_="category",
            axistick_opts=opts.AxisTickOpts(is_align_with_label=True),
            axisline_opts=opts.AxisLineOpts(
                is_on_zero=False, linestyle_opts=opts.LineStyleOpts(color="#6e9ef1")
            ),
            axispointer_opts=opts.AxisPointerOpts(
                is_show=True, label=opts.LabelOpts(formatter=JsCode(js_formatter))
            ),
        ),
    )
    .add_yaxis(
        series_name="2015 降水量",
        is_smooth=True,
        symbol="emptyCircle",
        is_symbol_show=False,
        # xaxis_index=1,
        color="#d14a61",
        y_axis=[2.6, 5.9, 9.0, 26.4, 28.7, 70.7, 175.6, 182.2, 48.7, 18.8, 6.0, 2.3],
        label_opts=opts.LabelOpts(is_show=False),
        linestyle_opts=opts.LineStyleOpts(width=2),
    )
    .add_yaxis(
        series_name="2016 降水量",
        is_smooth=True,
        symbol="emptyCircle",
        is_symbol_show=False,
        color="#6e9ef1",
        y_axis=[3.9, 5.9, 11.1, 18.7, 48.3, 69.2, 231.6, 46.6, 55.4, 18.4, 10.3, 0.7],
        label_opts=opts.LabelOpts(is_show=False),
        linestyle_opts=opts.LineStyleOpts(width=1),
    )
    .set_global_opts(
        legend_opts=opts.LegendOpts(),
        tooltip_opts=opts.TooltipOpts(trigger="none", axis_pointer_type="cross"),
        xaxis_opts=opts.AxisOpts(
            type_="category",
            axistick_opts=opts.AxisTickOpts(is_align_with_label=True),
            axisline_opts=opts.AxisLineOpts(
                is_on_zero=False, linestyle_opts=opts.LineStyleOpts(color="#d14a61")
            ),
            axispointer_opts=opts.AxisPointerOpts(
                is_show=True, label=opts.LabelOpts(formatter=JsCode(js_formatter))
            ),
        ),
        yaxis_opts=opts.AxisOpts(
            type_="value",
            splitline_opts=opts.SplitLineOpts(
                is_show=True, linestyle_opts=opts.LineStyleOpts(opacity=1)
            ),
        ),
    )
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="be5295a7d15741749a1df795e1c247b1" style="width:1600px; height:800px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_be5295a7d15741749a1df795e1c247b1 = echarts.init(
#                     document.getElementById('be5295a7d15741749a1df795e1c247b1'), 'white', {renderer: 'canvas'});
#                 var option_be5295a7d15741749a1df795e1c247b1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#6e9ef1",
#         "#d14a61",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "2015 \u964d\u6c34\u91cf",
#             "connectNulls": false,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": false,
#             "smooth": true,
#             "step": false,
#             "data": [
#                 [
#                     "2016-1",
#                     2.6
#                 ],
#                 [
#                     "2016-2",
#                     5.9
#                 ],
#                 [
#                     "2016-3",
#                     9.0
#                 ],
#                 [
#                     "2016-4",
#                     26.4
#                 ],
#                 [
#                     "2016-5",
#                     28.7
#                 ],
#                 [
#                     "2016-6",
#                     70.7
#                 ],
#                 [
#                     "2016-7",
#                     175.6
#                 ],
#                 [
#                     "2016-8",
#                     182.2
#                 ],
#                 [
#                     "2016-9",
#                     48.7
#                 ],
#                 [
#                     "2016-10",
#                     18.8
#                 ],
#                 [
#                     "2016-11",
#                     6.0
#                 ],
#                 [
#                     "2016-12",
#                     2.3
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 2,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "2016 \u964d\u6c34\u91cf",
#             "connectNulls": false,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "showSymbol": false,
#             "smooth": true,
#             "step": false,
#             "data": [
#                 [
#                     "2016-1",
#                     3.9
#                 ],
#                 [
#                     "2016-2",
#                     5.9
#                 ],
#                 [
#                     "2016-3",
#                     11.1
#                 ],
#                 [
#                     "2016-4",
#                     18.7
#                 ],
#                 [
#                     "2016-5",
#                     48.3
#                 ],
#                 [
#                     "2016-6",
#                     69.2
#                 ],
#                 [
#                     "2016-7",
#                     231.6
#                 ],
#                 [
#                     "2016-8",
#                     46.6
#                 ],
#                 [
#                     "2016-9",
#                     55.4
#                 ],
#                 [
#                     "2016-10",
#                     18.4
#                 ],
#                 [
#                     "2016-11",
#                     10.3
#                 ],
#                 [
#                     "2016-12",
#                     0.7
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "2015 \u964d\u6c34\u91cf",
#                 "2016 \u964d\u6c34\u91cf"
#             ],
#             "selected": {
#                 "2015 \u964d\u6c34\u91cf": true,
#                 "2016 \u964d\u6c34\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "none",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "cross"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": false,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#d14a61"
#                 }
#             },
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": true,
#                 "inside": false
#             },
#             "axisPointer": {
#                 "show": true,
#                 "type": "line",
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8,
#                     "formatter": function (params) {        console.log(params);        return '\u964d\u6c34\u91cf  ' + params.value + (params.seriesData.length ? '\uff1a' + params.seriesData[0].data : '')    }
#                 }
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2016-1",
#                 "2016-2",
#                 "2016-3",
#                 "2016-4",
#                 "2016-5",
#                 "2016-6",
#                 "2016-7",
#                 "2016-8",
#                 "2016-9",
#                 "2016-10",
#                 "2016-11",
#                 "2016-12"
#             ]
#         },
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,

# %% [markdown]
# ### 自定义特殊点/均线

# %%
import pyecharts.options as opts
from pyecharts.charts import Line
from pyecharts.faker import Faker

c = (
    Line()
    .add_xaxis(Faker.choose())
    .add_yaxis(
        "商家A",
        Faker.values(),
        markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_="min")]),  # markpoint_opts设置最小值
    )
    .add_yaxis(
        "商家B",
        Faker.values(),
        markline_opts=opts.MarkLineOpts(data=[opts.MarkLineItem(type_="average")]),  # markline_opts设置平均值
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="自定义特殊点-MarkPoint"))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9b602e96284d42b6943523ef29d9b1ea" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9b602e96284d42b6943523ef29d9b1ea = echarts.init(
#                     document.getElementById('9b602e96284d42b6943523ef29d9b1ea'), 'white', {renderer: 'canvas'});
#                 var option_9b602e96284d42b6943523ef29d9b1ea = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u53ef\u4e50",
#                     109
#                 ],
#                 [
#                     "\u96ea\u78a7",
#                     108
#                 ],
#                 [
#                     "\u6a59\u6c41",
#                     25
#                 ],
#                 [
#                     "\u7eff\u8336",
#                     62
#                 ],
#                 [
#                     "\u5976\u8336",
#                     56
#                 ],
#                 [
#                     "\u767e\u5a01",
#                     136
#                 ],
#                 [
#                     "\u9752\u5c9b",
#                     21
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "type": "min"
#                     }
#                 ]
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u53ef\u4e50",
#                     58
#                 ],
#                 [
#                     "\u96ea\u78a7",
#                     146
#                 ],
#                 [
#                     "\u6a59\u6c41",
#                     134
#                 ],
#                 [
#                     "\u7eff\u8336",
#                     51
#                 ],
#                 [
#                     "\u5976\u8336",
#                     94
#                 ],
#                 [
#                     "\u767e\u5a01",
#                     61
#                 ],
#                 [
#                     "\u9752\u5c9b",
#                     62
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "type": "average"
#                     }
#                 ]
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u81ea\u5b9a\u4e49\u7279\u6b8a\u70b9-MarkPoint",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_9b602e96284d42b6943523ef29d9b1ea.setOption(option_9b602e96284d42b6943523ef29d9b1ea);
#         });
#     </script>

# %% [markdown]
# ### JsCode使用

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.commons.utils import JsCode
from pyecharts.globals import ThemeType

# 添加两组数据：数值+百分比
list1 = [
    {"value": 12, "percent": 12 / (12 + 3)},
    {"value": 23, "percent": 23 / (23 + 21)},
    {"value": 33, "percent": 33 / (33 + 5)},
]

list2 = [
    {"value": 3, "percent": 3 / (12 + 3)},
    {"value": 21, "percent": 21 / (23 + 21)},
    {"value": 5, "percent": 5 / (33 + 5)},
]

c = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add_xaxis([1, 2, 3])
    .add_yaxis("product1", list1, stack="stack1", category_gap="50%")  # 如果两个stack设置不同，则表示为并排显示，相同则表示为堆叠显示
    .add_yaxis("product2", list2, stack="stack1", category_gap="50%")
    .set_series_opts(
        label_opts=opts.LabelOpts(
            position="right",
            formatter=JsCode("function(x){return Number(x.data.percent * 100).toFixed() + '%';}"),
        )
    )
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="dcb5fef6ee9d4b99ba5a1d30d4a6d6b4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_dcb5fef6ee9d4b99ba5a1d30d4a6d6b4 = echarts.init(
#                     document.getElementById('dcb5fef6ee9d4b99ba5a1d30d4a6d6b4'), 'light', {renderer: 'canvas'});
#                 var option_dcb5fef6ee9d4b99ba5a1d30d4a6d6b4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "product1",
#             "data": [
#                 {
#                     "value": 12,
#                     "percent": 0.8
#                 },
#                 {
#                     "value": 23,
#                     "percent": 0.5227272727272727
#                 },
#                 {
#                     "value": 33,
#                     "percent": 0.868421052631579
#                 }
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": function(x){return Number(x.data.percent * 100).toFixed() + '%';}
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "product2",
#             "data": [
#                 {
#                     "value": 3,
#                     "percent": 0.2
#                 },
#                 {
#                     "value": 21,
#                     "percent": 0.4772727272727273
#                 },
#                 {
#                     "value": 5,
#                     "percent": 0.13157894736842105
#                 }
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": function(x){return Number(x.data.percent * 100).toFixed() + '%';}
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "product1",
#                 "product2"
#             ],
#             "selected": {
#                 "product1": true,
#                 "product2": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 1,
#                 2,
#                 3
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_dcb5fef6ee9d4b99ba5a1d30d4a6d6b4.setOption(option_dcb5fef6ee9d4b99ba5a1d30d4a6d6b4);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.commons.utils import JsCode
from pyecharts.globals import ThemeType

# 添加两组数据：数值+百分比
list1 = [
    {"value": 12, "percent": 12 / (12 + 3)},
    {"value": 23, "percent": 23 / (23 + 21)},
    {"value": 33, "percent": 33 / (33 + 5)},
]

list2 = [
    {"value": 3, "percent": 3 / (12 + 3)},
    {"value": 21, "percent": 21 / (23 + 21)},
    {"value": 5, "percent": 5 / (33 + 5)},
]

c = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add_xaxis([1, 2, 3])
    # stack设置不同则表示为并行排列
    .add_yaxis("product1", list1, stack="stack2", category_gap="50%")
    .add_yaxis("product2", list2, stack="stack1", category_gap="50%")
    .set_series_opts(
        label_opts=opts.LabelOpts(
            position="top",  # 百分比显示的位置
            formatter=JsCode("function(x){return Number(x.data.percent * 100).toFixed() + '%';}"),
        )
    )
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="07028ca402804e7ab7cbd3fbbca3ba39" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_07028ca402804e7ab7cbd3fbbca3ba39 = echarts.init(
#                     document.getElementById('07028ca402804e7ab7cbd3fbbca3ba39'), 'light', {renderer: 'canvas'});
#                 var option_07028ca402804e7ab7cbd3fbbca3ba39 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "product1",
#             "data": [
#                 {
#                     "value": 12,
#                     "percent": 0.8
#                 },
#                 {
#                     "value": 23,
#                     "percent": 0.5227272727272727
#                 },
#                 {
#                     "value": 33,
#                     "percent": 0.868421052631579
#                 }
#             ],
#             "stack": "stack2",
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": function(x){return Number(x.data.percent * 100).toFixed() + '%';}
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "product2",
#             "data": [
#                 {
#                     "value": 3,
#                     "percent": 0.2
#                 },
#                 {
#                     "value": 21,
#                     "percent": 0.4772727272727273
#                 },
#                 {
#                     "value": 5,
#                     "percent": 0.13157894736842105
#                 }
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": function(x){return Number(x.data.percent * 100).toFixed() + '%';}
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "product1",
#                 "product2"
#             ],
#             "selected": {
#                 "product1": true,
#                 "product2": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 1,
#                 2,
#                 3
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_07028ca402804e7ab7cbd3fbbca3ba39.setOption(option_07028ca402804e7ab7cbd3fbbca3ba39);
#         });
#     </script>
