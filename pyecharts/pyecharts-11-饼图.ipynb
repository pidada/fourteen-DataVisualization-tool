# %% [markdown]
# ### 导入库

# %%
from pyecharts.globals import CurrentConfig, OnlineHostType   # 事先导入，防止不出图
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.charts import Pie
from pyecharts.faker import Faker
from pyecharts.commons.utils import JsCode
from pyecharts.globals import ThemeType

import pandas as pd
import numpy as np

# %% [markdown]
# ### 基本示例

# %%
# 一份月度开支数据

df = pd.read_excel("life.xlsx",sheet_name=1).head(5)
df
# Out:
#     父类  子类    数据
# 0  总费用  住宿  2580
# 1  总费用  餐饮  1300
# 2  总费用  交通   500
# 3  总费用  服装   900
# 4  总费用  红包  1300

# %%
x_data = df["子类"].tolist()
x_data
# Out:
# ['住宿', '餐饮', '交通', '服装', '红包']

# %%
y_data = df["数据"].tolist()
y_data
# Out:
# [2580, 1300, 500, 900, 1300]

# %%
c = (
    Pie()
    .add("", [list(z) for z in zip(x_data, y_data)])
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-月度开支"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="600f4800235245abb629cf80c78e9eae" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_600f4800235245abb629cf80c78e9eae = echarts.init(
#                     document.getElementById('600f4800235245abb629cf80c78e9eae'), 'white', {renderer: 'canvas'});
#                 var option_600f4800235245abb629cf80c78e9eae = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u4f4f\u5bbf",
#                     "value": 2580
#                 },
#                 {
#                     "name": "\u9910\u996e",
#                     "value": 1300
#                 },
#                 {
#                     "name": "\u4ea4\u901a",
#                     "value": 500
#                 },
#                 {
#                     "name": "\u670d\u88c5",
#                     "value": 900
#                 },
#                 {
#                     "name": "\u7ea2\u5305",
#                     "value": 1300
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4f4f\u5bbf",
#                 "\u9910\u996e",
#                 "\u4ea4\u901a",
#                 "\u670d\u88c5",
#                 "\u7ea2\u5305"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u6708\u5ea6\u5f00\u652f",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_600f4800235245abb629cf80c78e9eae.setOption(option_600f4800235245abb629cf80c78e9eae);
#         });
#     </script>

# %% [markdown]
# ### 改变位置和颜色

# %%
c = (
    Pie()
    .add("", 
         [list(z) for z in zip(x_data, y_data)],
         center=["30%", "50%"],) # 1、距离左边和上边的距离百分比
    .set_colors(["blue", "green", "purple", "red", "pink"])  # 2、改变颜色
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-月度开支"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f9695841d117475c838d617ca2dfa30d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f9695841d117475c838d617ca2dfa30d = echarts.init(
#                     document.getElementById('f9695841d117475c838d617ca2dfa30d'), 'white', {renderer: 'canvas'});
#                 var option_f9695841d117475c838d617ca2dfa30d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "blue",
#         "green",
#         "purple",
#         "red",
#         "pink"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u4f4f\u5bbf",
#                     "value": 2580
#                 },
#                 {
#                     "name": "\u9910\u996e",
#                     "value": 1300
#                 },
#                 {
#                     "name": "\u4ea4\u901a",
#                     "value": 500
#                 },
#                 {
#                     "name": "\u670d\u88c5",
#                     "value": 900
#                 },
#                 {
#                     "name": "\u7ea2\u5305",
#                     "value": 1300
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "30%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4f4f\u5bbf",
#                 "\u9910\u996e",
#                 "\u4ea4\u901a",
#                 "\u670d\u88c5",
#                 "\u7ea2\u5305"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u6708\u5ea6\u5f00\u652f",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_f9695841d117475c838d617ca2dfa30d.setOption(option_f9695841d117475c838d617ca2dfa30d);
#         });
#     </script>

# %% [markdown]
# ### 图例滚动

# %%
Faker.choose()   # 标签
# Out:
# ['草莓', '芒果', '葡萄', '雪梨', '西瓜', '柠檬', '车厘子']

# %%
Faker.choose()
# Out:
# ['衬衫', '毛衣', '领带', '裤子', '风衣', '高跟鞋', '袜子']

# %%
Faker.choose()
# Out:
# ['小米', '三星', '华为', '苹果', '魅族', 'VIVO', 'OPPO']

# %%
Faker.values()  # 数据
# Out:
# [121, 28, 75, 86, 142, 135, 41]

# %%
Faker.values()
# Out:
# [95, 105, 57, 124, 84, 113, 136]

# %%
Faker.values()
# Out:
# [97, 139, 142, 59, 128, 20, 62]

# %%
c = (
    Pie()
    .add(
        "",
        [
            list(z)
            for z in zip(
                Faker.choose() + Faker.choose() + Faker.choose() + Faker.choose(),
                Faker.values() + Faker.values() + Faker.values() + Faker.values(),
            )
        ],
        center=["40%", "50%"],
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Pie-图例滚动"),
        legend_opts=opts.LegendOpts(type_="scroll", pos_left="80%", orient="vertical"),
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3a39240ae9c04871b4047450bd1644cd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3a39240ae9c04871b4047450bd1644cd = echarts.init(
#                     document.getElementById('3a39240ae9c04871b4047450bd1644cd'), 'white', {renderer: 'canvas'});
#                 var option_3a39240ae9c04871b4047450bd1644cd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u53ef\u4e50",
#                     "value": 70
#                 },
#                 {
#                     "name": "\u96ea\u78a7",
#                     "value": 118
#                 },
#                 {
#                     "name": "\u6a59\u6c41",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u7eff\u8336",
#                     "value": 93
#                 },
#                 {
#                     "name": "\u5976\u8336",
#                     "value": 125
#                 },
#                 {
#                     "name": "\u767e\u5a01",
#                     "value": 132
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 101
#                 },
#                 {
#                     "name": "\u54c8\u58eb\u5947",
#                     "value": 89
#                 },
#                 {
#                     "name": "\u8428\u6469\u8036",
#                     "value": 26
#                 },
#                 {
#                     "name": "\u6cf0\u8fea",
#                     "value": 65
#                 },
#                 {
#                     "name": "\u91d1\u6bdb",
#                     "value": 129
#                 },
#                 {
#                     "name": "\u7267\u7f8a\u72ac",
#                     "value": 49
#                 },
#                 {
#                     "name": "\u5409\u5a03\u5a03",
#                     "value": 25
#                 },
#                 {
#                     "name": "\u67ef\u57fa",
#                     "value": 139
#                 },
#                 {
#                     "name": "\u5c0f\u7c73",
#                     "value": 139
#                 },
#                 {
#                     "name": "\u4e09\u661f",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u534e\u4e3a",
#                     "value": 84
#                 },
#                 {
#                     "name": "\u82f9\u679c",
#                     "value": 110
#                 },
#                 {
#                     "name": "\u9b45\u65cf",
#                     "value": 90
#                 },
#                 {
#                     "name": "VIVO",
#                     "value": 108
#                 },
#                 {
#                     "name": "OPPO",
#                     "value": 47
#                 },
#                 {
#                     "name": "\u5468\u4e00",
#                     "value": 110
#                 },
#                 {
#                     "name": "\u5468\u4e8c",
#                     "value": 110
#                 },
#                 {
#                     "name": "\u5468\u4e09",
#                     "value": 91
#                 },
#                 {
#                     "name": "\u5468\u56db",
#                     "value": 149
#                 },
#                 {
#                     "name": "\u5468\u4e94",
#                     "value": 112
#                 },
#                 {
#                     "name": "\u5468\u516d",
#                     "value": 144
#                 },
#                 {
#                     "name": "\u5468\u65e5",
#                     "value": 131
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "40%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b",
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa",
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO",
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "left": "80%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u56fe\u4f8b\u6eda\u52a8",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_3a39240ae9c04871b4047450bd1644cd.setOption(option_3a39240ae9c04871b4047450bd1644cd);
#         });
#     </script>

# %% [markdown]
# ### 环形饼图（中间空）

# %%
x_data = ["直接访问", "邮件营销", "联盟广告", "视频广告", "搜索引擎"]
y_data = [335, 310, 234, 135, 1548]

c = (
    Pie(init_opts=opts.InitOpts(width="1600px", height="1000px"))   # 图形的大小设置
    .add(
        series_name="访问来源",
        data_pair=[list(z) for z in zip(x_data, y_data)],
        radius=["15%", "50%"],   # 内圈和外圈的大小
        center=["30%", "50%"],   # 左边距和上边距
        label_opts=opts.LabelOpts(is_show=True),   # 显示数据和百分比  
    )
    .set_global_opts(legend_opts=opts.LegendOpts(pos_left="left", orient="vertical"))   # 图例在左边和垂直显示
    .set_series_opts(
        tooltip_opts=opts.TooltipOpts(
            trigger="item", formatter="{a} <br/>{b}: {c} ({d}%)"
        ),
    )
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7bc6bbf858ca405c822961483562da60" style="width:1600px; height:1000px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7bc6bbf858ca405c822961483562da60 = echarts.init(
#                     document.getElementById('7bc6bbf858ca405c822961483562da60'), 'white', {renderer: 'canvas'});
#                 var option_7bc6bbf858ca405c822961483562da60 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u8bbf\u95ee\u6765\u6e90",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u76f4\u63a5\u8bbf\u95ee",
#                     "value": 335
#                 },
#                 {
#                     "name": "\u90ae\u4ef6\u8425\u9500",
#                     "value": 310
#                 },
#                 {
#                     "name": "\u8054\u76df\u5e7f\u544a",
#                     "value": 234
#                 },
#                 {
#                     "name": "\u89c6\u9891\u5e7f\u544a",
#                     "value": 135
#                 },
#                 {
#                     "name": "\u641c\u7d22\u5f15\u64ce",
#                     "value": 1548
#                 }
#             ],
#             "radius": [
#                 "15%",
#                 "50%"
#             ],
#             "center": [
#                 "30%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "formatter": "{a} <br/>{b}: {c} ({d}%)",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u76f4\u63a5\u8bbf\u95ee",
#                 "\u90ae\u4ef6\u8425\u9500",
#                 "\u8054\u76df\u5e7f\u544a",
#                 "\u89c6\u9891\u5e7f\u544a",
#                 "\u641c\u7d22\u5f15\u64ce"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "left",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_7bc6bbf858ca405c822961483562da60.setOption(option_7bc6bbf858ca405c822961483562da60);
#         });
#     </script>

# %% [markdown]
# ### 多饼图

# %%
c = (
    Pie()
    .add(
        "",
        [list(z) for z in zip(["剧情", "其他"], [30, 70])],
        center=["20%", "30%"],  # 位置设置
        radius=[60, 80],   # 每个饼图内外圈的大小
    )
    .add(
        "",
        [list(z) for z in zip(["奇幻", "其他"], [40, 60])],
        center=["55%", "30%"],
        radius=[60, 80],
    )
    .add(
        "",
        [list(z) for z in zip(["爱情", "其他"], [24, 76])],
        center=["20%", "70%"],
        radius=[60, 80],
    )
    .add(
        "",
        [list(z) for z in zip(["惊悚", "其他"], [11, 89])],
        center=["55%", "70%"],
        radius=[60, 80],
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Pie-多饼图基本示例"),
        legend_opts=opts.LegendOpts(
            type_="scroll", pos_top="20%", pos_left="80%", orient="vertical"
        ),
    )
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="da98ffa8cfb04b93ad2cd890cc5931b4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_da98ffa8cfb04b93ad2cd890cc5931b4 = echarts.init(
#                     document.getElementById('da98ffa8cfb04b93ad2cd890cc5931b4'), 'white', {renderer: 'canvas'});
#                 var option_da98ffa8cfb04b93ad2cd890cc5931b4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5267\u60c5",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 70
#                 }
#             ],
#             "radius": [
#                 60,
#                 80
#             ],
#             "center": [
#                 "20%",
#                 "30%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5947\u5e7b",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 60
#                 }
#             ],
#             "radius": [
#                 60,
#                 80
#             ],
#             "center": [
#                 "55%",
#                 "30%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u7231\u60c5",
#                     "value": 24
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 76
#                 }
#             ],
#             "radius": [
#                 60,
#                 80
#             ],
#             "center": [
#                 "20%",
#                 "70%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u60ca\u609a",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 89
#                 }
#             ],
#             "radius": [
#                 60,
#                 80
#             ],
#             "center": [
#                 "55%",
#                 "70%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5267\u60c5",
#                 "\u5176\u4ed6",
#                 "\u5947\u5e7b",
#                 "\u7231\u60c5",
#                 "\u60ca\u609a"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "left": "80%",
#             "top": "20%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u591a\u997c\u56fe\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_da98ffa8cfb04b93ad2cd890cc5931b4.setOption(option_da98ffa8cfb04b93ad2cd890cc5931b4);
#         });
#     </script>

# %% [markdown]
# ### 玫瑰图

# %%
v = Faker.choose()
c = (
    Pie()
    .add(
        "",
        [list(z) for z in zip(v, Faker.values())],   # 两个值
        radius=["30%", "60%"],  # 大小
        center=["25%", "50%"],  # 位置
        rosetype="radius",
        label_opts=opts.LabelOpts(is_show=False),
    )
    .add(
        "",
        [list(z) for z in zip(v, Faker.values())],
        radius=["30%", "60%"],
        center=["75%", "50%"],
        rosetype="area",
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-玫瑰图示例"))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d09afd393573485fb9de58268a13339a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d09afd393573485fb9de58268a13339a = echarts.init(
#                     document.getElementById('d09afd393573485fb9de58268a13339a'), 'white', {renderer: 'canvas'});
#                 var option_d09afd393573485fb9de58268a13339a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 73
#                 },
#                 {
#                     "name": "\u6bdb\u8863",
#                     "value": 52
#                 },
#                 {
#                     "name": "\u9886\u5e26",
#                     "value": 118
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 27
#                 },
#                 {
#                     "name": "\u98ce\u8863",
#                     "value": 79
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 113
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 65
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "60%"
#             ],
#             "center": [
#                 "25%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 110
#                 },
#                 {
#                     "name": "\u6bdb\u8863",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u9886\u5e26",
#                     "value": 118
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 144
#                 },
#                 {
#                     "name": "\u98ce\u8863",
#                     "value": 108
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 109
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 40
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "60%"
#             ],
#             "center": [
#                 "75%",
#                 "50%"
#             ],
#             "roseType": "area",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u73ab\u7470\u56fe\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_d09afd393573485fb9de58268a13339a.setOption(option_d09afd393573485fb9de58268a13339a);
#         });
#     </script>
