# %% [markdown]
# ### 导入库

# %%
from pyecharts.globals import CurrentConfig, OnlineHostType   # 事先导入，防止不出图
from pyecharts import options as opts   # 配置项
from pyecharts.charts import Pie
from pyecharts.faker import Faker   # 自带数据
from pyecharts.commons.utils import JsCode
from pyecharts.globals import ThemeType   # 主题

import pandas as pd

# %% [markdown]
# ### 基本示例

# %%
# 生成数据
df = pd.DataFrame({"消费":["住宿","餐饮","交通","服装","红包"],
                   "数据":[2580,1300,500,900,1300]
                  })
df
# Out:
#    消费    数据
# 0  住宿  2580
# 1  餐饮  1300
# 2  交通   500
# 3  服装   900
# 4  红包  1300

# %%
x_data = df["消费"].tolist()
x_data
# Out:
# ['住宿', '餐饮', '交通', '服装', '红包']

# %%
y_data = df["数据"].tolist()
y_data
# Out:
# [2580, 1300, 500, 900, 1300]

# %%
c = (
    Pie()
    .add("", [list(z) for z in zip(x_data, y_data)])
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-月度开支"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="dc48921bcadd442e8bbefdf8ab455ea4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_dc48921bcadd442e8bbefdf8ab455ea4 = echarts.init(
#                     document.getElementById('dc48921bcadd442e8bbefdf8ab455ea4'), 'white', {renderer: 'canvas'});
#                 var option_dc48921bcadd442e8bbefdf8ab455ea4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u4f4f\u5bbf",
#                     "value": 2580
#                 },
#                 {
#                     "name": "\u9910\u996e",
#                     "value": 1300
#                 },
#                 {
#                     "name": "\u4ea4\u901a",
#                     "value": 500
#                 },
#                 {
#                     "name": "\u670d\u88c5",
#                     "value": 900
#                 },
#                 {
#                     "name": "\u7ea2\u5305",
#                     "value": 1300
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4f4f\u5bbf",
#                 "\u9910\u996e",
#                 "\u4ea4\u901a",
#                 "\u670d\u88c5",
#                 "\u7ea2\u5305"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u6708\u5ea6\u5f00\u652f",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_dc48921bcadd442e8bbefdf8ab455ea4.setOption(option_dc48921bcadd442e8bbefdf8ab455ea4);
#         });
#     </script>

# %% [markdown]
# ### 改变位置和颜色

# %%
c = (
    Pie()
    .add("", 
         [list(z) for z in zip(x_data, y_data)],
         center=["30%", "50%"],) # 1、距离左边和上边的距离百分比
    .set_colors(["blue", "green", "purple", "red", "pink"])  # 2、改变颜色
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-月度开支"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b144657721f54d1db6295fb1a0eaf6f9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b144657721f54d1db6295fb1a0eaf6f9 = echarts.init(
#                     document.getElementById('b144657721f54d1db6295fb1a0eaf6f9'), 'white', {renderer: 'canvas'});
#                 var option_b144657721f54d1db6295fb1a0eaf6f9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "blue",
#         "green",
#         "purple",
#         "red",
#         "pink"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u4f4f\u5bbf",
#                     "value": 2580
#                 },
#                 {
#                     "name": "\u9910\u996e",
#                     "value": 1300
#                 },
#                 {
#                     "name": "\u4ea4\u901a",
#                     "value": 500
#                 },
#                 {
#                     "name": "\u670d\u88c5",
#                     "value": 900
#                 },
#                 {
#                     "name": "\u7ea2\u5305",
#                     "value": 1300
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "30%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4f4f\u5bbf",
#                 "\u9910\u996e",
#                 "\u4ea4\u901a",
#                 "\u670d\u88c5",
#                 "\u7ea2\u5305"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u6708\u5ea6\u5f00\u652f",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_b144657721f54d1db6295fb1a0eaf6f9.setOption(option_b144657721f54d1db6295fb1a0eaf6f9);
#         });
#     </script>

# %% [markdown]
# ### 图例滚动

# %%
Faker.choose()   # 标签
# Out:
# ['周一', '周二', '周三', '周四', '周五', '周六', '周日']

# %%
Faker.choose()
# Out:
# ['可乐', '雪碧', '橙汁', '绿茶', '奶茶', '百威', '青岛']

# %%
Faker.choose()
# Out:
# ['小米', '三星', '华为', '苹果', '魅族', 'VIVO', 'OPPO']

# %%
Faker.values()  # 数据
# Out:
# [102, 133, 35, 89, 118, 40, 112]

# %%
Faker.values()
# Out:
# [141, 122, 43, 104, 108, 113, 44]

# %%
Faker.values()
# Out:
# [112, 124, 27, 73, 128, 106, 64]

# %%
c = (
    Pie()
    .add(
        "",
        [list(z)for z in zip(
                Faker.choose() + Faker.choose() + Faker.choose() + Faker.choose(),
                Faker.values() + Faker.values() + Faker.values() + Faker.values(),
            )],
        center=["40%", "50%"],
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Pie-图例滚动"),
        legend_opts=opts.LegendOpts(type_="scroll", pos_left="80%", orient="vertical"),  # scroll 滚动图例；vertical：竖直显示
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5f48fc7112f1483c8fd84a9d96c1586a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5f48fc7112f1483c8fd84a9d96c1586a = echarts.init(
#                     document.getElementById('5f48fc7112f1483c8fd84a9d96c1586a'), 'white', {renderer: 'canvas'});
#                 var option_5f48fc7112f1483c8fd84a9d96c1586a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5468\u4e00",
#                     "value": 120
#                 },
#                 {
#                     "name": "\u5468\u4e8c",
#                     "value": 103
#                 },
#                 {
#                     "name": "\u5468\u4e09",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u5468\u56db",
#                     "value": 118
#                 },
#                 {
#                     "name": "\u5468\u4e94",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u5468\u516d",
#                     "value": 115
#                 },
#                 {
#                     "name": "\u5468\u65e5",
#                     "value": 93
#                 },
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 145
#                 },
#                 {
#                     "name": "\u6bdb\u8863",
#                     "value": 51
#                 },
#                 {
#                     "name": "\u9886\u5e26",
#                     "value": 75
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 139
#                 },
#                 {
#                     "name": "\u98ce\u8863",
#                     "value": 137
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 119
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u5468\u4e00",
#                     "value": 128
#                 },
#                 {
#                     "name": "\u5468\u4e8c",
#                     "value": 65
#                 },
#                 {
#                     "name": "\u5468\u4e09",
#                     "value": 116
#                 },
#                 {
#                     "name": "\u5468\u56db",
#                     "value": 47
#                 },
#                 {
#                     "name": "\u5468\u4e94",
#                     "value": 57
#                 },
#                 {
#                     "name": "\u5468\u516d",
#                     "value": 110
#                 },
#                 {
#                     "name": "\u5468\u65e5",
#                     "value": 51
#                 },
#                 {
#                     "name": "\u5c0f\u7c73",
#                     "value": 91
#                 },
#                 {
#                     "name": "\u4e09\u661f",
#                     "value": 81
#                 },
#                 {
#                     "name": "\u534e\u4e3a",
#                     "value": 143
#                 },
#                 {
#                     "name": "\u82f9\u679c",
#                     "value": 111
#                 },
#                 {
#                     "name": "\u9b45\u65cf",
#                     "value": 92
#                 },
#                 {
#                     "name": "VIVO",
#                     "value": 110
#                 },
#                 {
#                     "name": "OPPO",
#                     "value": 135
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "40%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5",
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50",
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "left": "80%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u56fe\u4f8b\u6eda\u52a8",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_5f48fc7112f1483c8fd84a9d96c1586a.setOption(option_5f48fc7112f1483c8fd84a9d96c1586a);
#         });
#     </script>

# %% [markdown]
# ### 环状饼图

# %%
x_data = ["小明", "小红", "张三", "李四", "王五"]
y_data = [335, 310, 234, 135, 548]

c = (
    Pie(init_opts=opts.InitOpts(width="1600px", height="1000px"))   # 图形的大小设置
    .add(
        series_name="访问来源",
        data_pair=[list(z) for z in zip(x_data, y_data)],
        radius=["15%", "50%"],   # 内圈和外圈的大小
        center=["30%", "40%"],   # 左边距和上边距
        label_opts=opts.LabelOpts(is_show=True),   # 显示数据和百分比  
    )
    .set_global_opts(legend_opts=opts.LegendOpts(pos_left="left", orient="vertical"))   # 图例在左边和垂直显示
    .set_series_opts(
        tooltip_opts=opts.TooltipOpts(
            trigger="item", formatter="{a} <br/>{b}: {c} ({d}%)"
        ),
    )
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1dcfedc0c6f04825976e409f5a526808" style="width:1600px; height:1000px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1dcfedc0c6f04825976e409f5a526808 = echarts.init(
#                     document.getElementById('1dcfedc0c6f04825976e409f5a526808'), 'white', {renderer: 'canvas'});
#                 var option_1dcfedc0c6f04825976e409f5a526808 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u8bbf\u95ee\u6765\u6e90",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5c0f\u660e",
#                     "value": 335
#                 },
#                 {
#                     "name": "\u5c0f\u7ea2",
#                     "value": 310
#                 },
#                 {
#                     "name": "\u5f20\u4e09",
#                     "value": 234
#                 },
#                 {
#                     "name": "\u674e\u56db",
#                     "value": 135
#                 },
#                 {
#                     "name": "\u738b\u4e94",
#                     "value": 548
#                 }
#             ],
#             "radius": [
#                 "15%",
#                 "50%"
#             ],
#             "center": [
#                 "30%",
#                 "40%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "formatter": "{a} <br/>{b}: {c} ({d}%)",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5c0f\u660e",
#                 "\u5c0f\u7ea2",
#                 "\u5f20\u4e09",
#                 "\u674e\u56db",
#                 "\u738b\u4e94"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "left",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_1dcfedc0c6f04825976e409f5a526808.setOption(option_1dcfedc0c6f04825976e409f5a526808);
#         });
#     </script>

# %% [markdown]
# ### 多饼图

# %%
c = (
    Pie()
    .add(
        "",
        [list(z) for z in zip(["剧情", "其他"], [30, 70])],
        center=["20%", "30%"],  # 位置设置
        radius=[60, 80],   # 每个饼图内外圈的大小
    )
    .add(
        "",
        [list(z) for z in zip(["奇幻", "其他"], [40, 60])],
        center=["55%", "30%"],
        radius=[60, 80],
    )
    .add(
        "",
        [list(z) for z in zip(["爱情", "其他"], [24, 76])],
        center=["20%", "70%"],
        radius=[60, 80],
    )
    .add(
        "",
        [list(z) for z in zip(["惊悚", "其他"], [11, 89])],
        center=["55%", "70%"],
        radius=[60, 80],
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Pie-多饼图基本示例"),
        legend_opts=opts.LegendOpts(
            type_="scroll", pos_top="20%", pos_left="80%", orient="vertical"
        ),
    )
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="04929e77dcfd43a280c4cc12bd415724" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_04929e77dcfd43a280c4cc12bd415724 = echarts.init(
#                     document.getElementById('04929e77dcfd43a280c4cc12bd415724'), 'white', {renderer: 'canvas'});
#                 var option_04929e77dcfd43a280c4cc12bd415724 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5267\u60c5",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 70
#                 }
#             ],
#             "radius": [
#                 60,
#                 80
#             ],
#             "center": [
#                 "20%",
#                 "30%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5947\u5e7b",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 60
#                 }
#             ],
#             "radius": [
#                 60,
#                 80
#             ],
#             "center": [
#                 "55%",
#                 "30%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u7231\u60c5",
#                     "value": 24
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 76
#                 }
#             ],
#             "radius": [
#                 60,
#                 80
#             ],
#             "center": [
#                 "20%",
#                 "70%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u60ca\u609a",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 89
#                 }
#             ],
#             "radius": [
#                 60,
#                 80
#             ],
#             "center": [
#                 "55%",
#                 "70%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5267\u60c5",
#                 "\u5176\u4ed6",
#                 "\u5947\u5e7b",
#                 "\u7231\u60c5",
#                 "\u60ca\u609a"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "left": "80%",
#             "top": "20%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u591a\u997c\u56fe\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_04929e77dcfd43a280c4cc12bd415724.setOption(option_04929e77dcfd43a280c4cc12bd415724);
#         });
#     </script>

# %% [markdown]
# ### 玫瑰图

# %%
v = Faker.choose()
c = (
    Pie()
    .add(
        "",
        [list(z) for z in zip(v, Faker.values())],   # 两个值
        radius=["30%", "60%"],  # 大小
        center=["25%", "50%"],  # 位置
        rosetype="radius",   
        label_opts=opts.LabelOpts(is_show=False),  # 不在图形上显示数据
    )
    .add(
        "",
        [list(z) for z in zip(v, Faker.values())],
        radius=["30%", "60%"],
        center=["75%", "50%"],
        rosetype="area",
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-玫瑰图示例"))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="768c6911cd1b4d679049fb199fc222e6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_768c6911cd1b4d679049fb199fc222e6 = echarts.init(
#                     document.getElementById('768c6911cd1b4d679049fb199fc222e6'), 'white', {renderer: 'canvas'});
#                 var option_768c6911cd1b4d679049fb199fc222e6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u6cb3\u9a6c",
#                     "value": 137
#                 },
#                 {
#                     "name": "\u87d2\u86c7",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u8001\u864e",
#                     "value": 142
#                 },
#                 {
#                     "name": "\u5927\u8c61",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u5154\u5b50",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u718a\u732b",
#                     "value": 25
#                 },
#                 {
#                     "name": "\u72ee\u5b50",
#                     "value": 89
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "60%"
#             ],
#             "center": [
#                 "25%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u6cb3\u9a6c",
#                     "value": 136
#                 },
#                 {
#                     "name": "\u87d2\u86c7",
#                     "value": 51
#                 },
#                 {
#                     "name": "\u8001\u864e",
#                     "value": 93
#                 },
#                 {
#                     "name": "\u5927\u8c61",
#                     "value": 29
#                 },
#                 {
#                     "name": "\u5154\u5b50",
#                     "value": 136
#                 },
#                 {
#                     "name": "\u718a\u732b",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u72ee\u5b50",
#                     "value": 33
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "60%"
#             ],
#             "center": [
#                 "75%",
#                 "50%"
#             ],
#             "roseType": "area",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u73ab\u7470\u56fe\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_768c6911cd1b4d679049fb199fc222e6.setOption(option_768c6911cd1b4d679049fb199fc222e6);
#         });
#     </script>

# %% [markdown]
# ### 内嵌饼图

# %%
import pyecharts.options as opts
from pyecharts.charts import Pie
from pyecharts.globals import ThemeType

# 内部饼图
inner_x_data = ["直达", "营销广告", "搜索引擎","产品"]
inner_y_data = [335, 679, 548, 283]
inner_data_pair = [list(z) for z in zip(inner_x_data, inner_y_data)]
# [['直达', 335], ['营销广告', 679], ['搜索引擎', 1548], [‘产品’, 283]]


# 外部环形（嵌套）
outer_x_data = ["搜索引擎", "邮件营销", "直达", "营销广告", "联盟广告", "视频广告", "产品", "百度", "谷歌","邮件营销", "联盟广告"]
outer_y_data = [335, 135, 147, 102, 220, 310, 234, 135, 648, 251]
outer_data_pair = [list(z) for z in zip(outer_x_data, outer_y_data)]


c = (
     # 初始化
    Pie(init_opts=opts.InitOpts(
        width="900px",
        height="800px",
        theme=ThemeType.SHINE))

    # 内部饼图
    .add(
        series_name="版本3.2.1",  # 系列名称
        center=["50%", "35%"],
        data_pair=inner_data_pair,  # 系列数据项，格式为 [(key1, value1), (key2, value2)]
        radius=["25%", "40%"],  #饼图半径 数组的第一项是内半径，第二项是外半径
        label_opts=opts.LabelOpts(position='inner'), #标签设置在内部
    )

    # 外部嵌套环形图
    .add(
        series_name="版本3.2.9",  # 系列名称
        center=["50%", "35%"],
        radius=["40%", "60%"],  #饼图半径 数组的第一项是内半径，第二项是外半径
        data_pair=outer_data_pair, # 系列数据项，格式为 [(key1, value1), (key2, value2)]

        # 标签配置项 参考上面的例子
        label_opts=opts.LabelOpts(
            position="outside",
            formatter="{a|{a}}{abg|}\n{hr|}\n {b|{b}: }{c}  {per|{d}%}  ",
            background_color="#eee",
            border_color="#aaa",
            border_width=1,
            border_radius=4,
            rich={
                "a": {"color": "#999",
                      "lineHeight": 22,
                      "align": "center"},

                "abg": {
                    "backgroundColor": "#e3e3e3",
                    "width": "100%",
                    "align": "right",
                    "height": 22,
                    "borderRadius": [4, 4, 0, 0],
                },


                "hr": {
                    "borderColor": "#aaa",
                    "width": "100%",
                    "borderWidth": 0.5,
                    "height": 0,
                },


                "b": {"fontSize": 16, "lineHeight": 33},


                "per": {
                    "color": "#eee",
                    "backgroundColor": "#334455",
                    "padding": [2, 4],
                    "borderRadius": 2,
                },
            },
        ),
    )

    # 全局配置项
    .set_global_opts(
        xaxis_opts = opts.AxisOpts(is_show = False),   #隐藏X轴刻度
        yaxis_opts = opts.AxisOpts(is_show = False),    #隐藏Y轴刻度
        legend_opts = opts.LegendOpts(is_show = True),  #隐藏图例
        title_opts = opts.TitleOpts(title = None),    #隐藏标题
                    )

    # 系统配置项
    .set_series_opts(
        tooltip_opts=opts.TooltipOpts(
            trigger="item",
            formatter="{a} <br/>{b}: {c} ({d}%)"
        ),
        label_opts=opts.LabelOpts(is_show=True)  # 隐藏每个触角标签
    )
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'shine':'https://assets.pyecharts.org/assets/themes/shine'
#         }
#     });
# </script>
#
#         <div id="1aa9972e19604b93ac38f2adb9090dde" style="width:900px; height:800px;"></div>
#
# <script>
#         require(['echarts', 'shine'], function(echarts) {
#                 var chart_1aa9972e19604b93ac38f2adb9090dde = echarts.init(
#                     document.getElementById('1aa9972e19604b93ac38f2adb9090dde'), 'shine', {renderer: 'canvas'});
#                 var option_1aa9972e19604b93ac38f2adb9090dde = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u7248\u672c3.2.1",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u76f4\u8fbe",
#                     "value": 335
#                 },
#                 {
#                     "name": "\u8425\u9500\u5e7f\u544a",
#                     "value": 679
#                 },
#                 {
#                     "name": "\u641c\u7d22\u5f15\u64ce",
#                     "value": 548
#                 },
#                 {
#                     "name": "\u4ea7\u54c1",
#                     "value": 283
#                 }
#             ],
#             "radius": [
#                 "25%",
#                 "40%"
#             ],
#             "center": [
#                 "50%",
#                 "35%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "formatter": "{a} <br/>{b}: {c} ({d}%)",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "pie",
#             "name": "\u7248\u672c3.2.9",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u641c\u7d22\u5f15\u64ce",
#                     "value": 335
#                 },
#                 {
#                     "name": "\u90ae\u4ef6\u8425\u9500",
#                     "value": 135
#                 },
#                 {
#                     "name": "\u76f4\u8fbe",
#                     "value": 147
#                 },
#                 {
#                     "name": "\u8425\u9500\u5e7f\u544a",
#                     "value": 102
#                 },
#                 {
#                     "name": "\u8054\u76df\u5e7f\u544a",
#                     "value": 220
#                 },
#                 {
#                     "name": "\u89c6\u9891\u5e7f\u544a",
#                     "value": 310
#                 },
#                 {
#                     "name": "\u4ea7\u54c1",
#                     "value": 234
#                 },
#                 {
#                     "name": "\u767e\u5ea6",
#                     "value": 135
#                 },
#                 {
#                     "name": "\u8c37\u6b4c",
#                     "value": 648
#                 },
#                 {
#                     "name": "\u90ae\u4ef6\u8425\u9500",
#                     "value": 251
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "60%"
#             ],
#             "center": [
#                 "50%",
#                 "35%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "formatter": "{a} <br/>{b}: {c} ({d}%)",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u76f4\u8fbe",
#                 "\u8425\u9500\u5e7f\u544a",
#                 "\u641c\u7d22\u5f15\u64ce",
#                 "\u4ea7\u54c1",
#                 "\u90ae\u4ef6\u8425\u9500",
#                 "\u8054\u76df\u5e7f\u544a",
#                 "\u89c6\u9891\u5e7f\u544a",
#                 "\u767e\u5ea6",
#                 "\u8c37\u6b4c"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_1aa9972e19604b93ac38f2adb9090dde.setOption(option_1aa9972e19604b93ac38f2adb9090dde);
#         });
#     </script>
