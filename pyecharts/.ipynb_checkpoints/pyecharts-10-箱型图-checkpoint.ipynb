# %% [markdown]
# ### 导入库

# %%
from pyecharts.globals import CurrentConfig, OnlineHostType   # 事先导入，防止不出图
from pyecharts import options as opts
from pyecharts.charts import Boxplot
from pyecharts.faker import Faker
from pyecharts.commons.utils import JsCode
from pyecharts.globals import ThemeType

import pandas as pd
import numpy as np

# %% [markdown]
# ### 基本示例

# %%
x =['class1','class2','class3']

y1 = np.random.randint(0,100,10).tolist()
y2 = np.random.randint(0,100,10).tolist()
y3 = np.random.randint(0,100,10).tolist()
y4 = np.random.randint(0,100,10).tolist()

# %%
print(y1)
print(y2)
print(y3)
print(y4)
# Out:
# [7, 15, 23, 37, 57, 25, 74, 45, 18, 70]
# [9, 9, 16, 30, 2, 13, 7, 49, 88, 76]
# [66, 55, 81, 39, 77, 4, 95, 82, 38, 85]
# [26, 17, 5, 0, 95, 18, 76, 14, 22, 24]

# %%
c = Boxplot(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))

c.add_xaxis(x)   # x轴标记
c.add_yaxis("成绩对比",c.prepare_data([y1,y2]))  # y1,y2,y3,y4本身就是列表，还需要放在列表中
c.add_yaxis("成绩对比",c.prepare_data([y3,y4]))  
c.set_global_opts(title_opts=opts.TitleOpts(title="成绩对比"))

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="59788198aa4940fa82070c9ec87cf239" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_59788198aa4940fa82070c9ec87cf239 = echarts.init(
#                     document.getElementById('59788198aa4940fa82070c9ec87cf239'), 'light', {renderer: 'canvas'});
#                 var option_59788198aa4940fa82070c9ec87cf239 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "\u6210\u7ee9\u5bf9\u6bd4",
#             "data": [
#                 [
#                     7,
#                     17.25,
#                     31.0,
#                     60.25,
#                     74
#                 ],
#                 [
#                     2,
#                     8.5,
#                     14.5,
#                     55.75,
#                     88
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "\u6210\u7ee9\u5bf9\u6bd4",
#             "data": [
#                 [
#                     4,
#                     38.75,
#                     71.5,
#                     82.75,
#                     95
#                 ],
#                 [
#                     0,
#                     11.75,
#                     20.0,
#                     38.5,
#                     95
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6210\u7ee9\u5bf9\u6bd4",
#                 "\u6210\u7ee9\u5bf9\u6bd4"
#             ],
#             "selected": {
#                 "\u6210\u7ee9\u5bf9\u6bd4": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "class1",
#                 "class2",
#                 "class3"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6210\u7ee9\u5bf9\u6bd4",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_59788198aa4940fa82070c9ec87cf239.setOption(option_59788198aa4940fa82070c9ec87cf239);
#         });
#     </script>

# %%
# 链式调用

c = (
    Boxplot()
    .add_xaxis(["class1","class2"])   # x轴标记
    .add_yaxis("A",c.prepare_data([y1,y2]))  # y1,y2,y3,y4本身就是列表，还需要放在列表中
    .add_yaxis("B",c.prepare_data([y3,y4]))  
    .set_global_opts(title_opts=opts.TitleOpts(title="成绩对比"))
    )

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a0505391eb12430d9971e206844924ea" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a0505391eb12430d9971e206844924ea = echarts.init(
#                     document.getElementById('a0505391eb12430d9971e206844924ea'), 'white', {renderer: 'canvas'});
#                 var option_a0505391eb12430d9971e206844924ea = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "A",
#             "data": [
#                 [
#                     7,
#                     17.25,
#                     31.0,
#                     60.25,
#                     74
#                 ],
#                 [
#                     2,
#                     8.5,
#                     14.5,
#                     55.75,
#                     88
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "B",
#             "data": [
#                 [
#                     4,
#                     38.75,
#                     71.5,
#                     82.75,
#                     95
#                 ],
#                 [
#                     0,
#                     11.75,
#                     20.0,
#                     38.5,
#                     95
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "class1",
#                 "class2"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6210\u7ee9\u5bf9\u6bd4",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_a0505391eb12430d9971e206844924ea.setOption(option_a0505391eb12430d9971e206844924ea);
#         });
#     </script>
