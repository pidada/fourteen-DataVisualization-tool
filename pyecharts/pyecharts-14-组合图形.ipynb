# %% [markdown]
# ### 导入库

# %%
from pyecharts.globals import CurrentConfig, OnlineHostType   # 事先导入，防止不出图
from pyecharts import options as opts  # 配置项
from pyecharts.charts import Bar, Pie, Line, HeatMap, Funnel, Gauge, Grid, Page  # 各个图形的类
from pyecharts.faker import Faker  # 自身数据
from pyecharts.commons.utils import JsCode   
from pyecharts.globals import ThemeType,SymbolType

import pandas as pd
import numpy as np
import random

# %% [markdown]
# ### 模拟数据

# %%
df = pd.DataFrame({"消费":["住宿","餐饮","交通","服装","红包"],
                  "数据":[1800,900,420,600,1500]})

df
# Out:
#    消费    数据
# 0  住宿  1800
# 1  餐饮   900
# 2  交通   420
# 3  服装   600
# 4  红包  1500

# %% [markdown]
# ### 柱状图

# %%
bar = (
    Bar()
    .add_xaxis(df['消费'].tolist())
    .add_yaxis("5大开支",df['数据'].tolist())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Bar-月度开支"),
        legend_opts=opts.LegendOpts(is_show=False),
    )
)

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0c7ead8c1fb949fd83d23e22722914a4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0c7ead8c1fb949fd83d23e22722914a4 = echarts.init(
#                     document.getElementById('0c7ead8c1fb949fd83d23e22722914a4'), 'white', {renderer: 'canvas'});
#                 var option_0c7ead8c1fb949fd83d23e22722914a4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "5\u5927\u5f00\u652f",
#             "data": [
#                 1800,
#                 900,
#                 420,
#                 600,
#                 1500
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "5\u5927\u5f00\u652f"
#             ],
#             "selected": {
#                 "5\u5927\u5f00\u652f": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4f4f\u5bbf",
#                 "\u9910\u996e",
#                 "\u4ea4\u901a",
#                 "\u670d\u88c5",
#                 "\u7ea2\u5305"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u6708\u5ea6\u5f00\u652f",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_0c7ead8c1fb949fd83d23e22722914a4.setOption(option_0c7ead8c1fb949fd83d23e22722914a4);
#         });
#     </script>

# %% [markdown]
# ### 饼图

# %%
pie = (
    Pie()
    .add("", [list(z) for z in zip(df['消费'].tolist(), df['数据'].tolist())])
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-月度开支"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)

pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="51fc015bc7cd47f1b0b9b55002c44450" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_51fc015bc7cd47f1b0b9b55002c44450 = echarts.init(
#                     document.getElementById('51fc015bc7cd47f1b0b9b55002c44450'), 'white', {renderer: 'canvas'});
#                 var option_51fc015bc7cd47f1b0b9b55002c44450 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u4f4f\u5bbf",
#                     "value": 1800
#                 },
#                 {
#                     "name": "\u9910\u996e",
#                     "value": 900
#                 },
#                 {
#                     "name": "\u4ea4\u901a",
#                     "value": 420
#                 },
#                 {
#                     "name": "\u670d\u88c5",
#                     "value": 600
#                 },
#                 {
#                     "name": "\u7ea2\u5305",
#                     "value": 1500
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4f4f\u5bbf",
#                 "\u9910\u996e",
#                 "\u4ea4\u901a",
#                 "\u670d\u88c5",
#                 "\u7ea2\u5305"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u6708\u5ea6\u5f00\u652f",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_51fc015bc7cd47f1b0b9b55002c44450.setOption(option_51fc015bc7cd47f1b0b9b55002c44450);
#         });
#     </script>

# %% [markdown]
# ### 折线图

# %%
line = (
    Line()
    .add_xaxis(df['消费'].tolist())
    .add_yaxis("月度开支", df['数据'].tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="Line-月度开支"))
)

line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8976c3409bb74b359012e5cd47c3681a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8976c3409bb74b359012e5cd47c3681a = echarts.init(
#                     document.getElementById('8976c3409bb74b359012e5cd47c3681a'), 'white', {renderer: 'canvas'});
#                 var option_8976c3409bb74b359012e5cd47c3681a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u6708\u5ea6\u5f00\u652f",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u4f4f\u5bbf",
#                     1800
#                 ],
#                 [
#                     "\u9910\u996e",
#                     900
#                 ],
#                 [
#                     "\u4ea4\u901a",
#                     420
#                 ],
#                 [
#                     "\u670d\u88c5",
#                     600
#                 ],
#                 [
#                     "\u7ea2\u5305",
#                     1500
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6708\u5ea6\u5f00\u652f"
#             ],
#             "selected": {
#                 "\u6708\u5ea6\u5f00\u652f": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4f4f\u5bbf",
#                 "\u9910\u996e",
#                 "\u4ea4\u901a",
#                 "\u670d\u88c5",
#                 "\u7ea2\u5305"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Line-\u6708\u5ea6\u5f00\u652f",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_8976c3409bb74b359012e5cd47c3681a.setOption(option_8976c3409bb74b359012e5cd47c3681a);
#         });
#     </script>

# %% [markdown]
# ### 热力图

# %%
print(Faker.week)
# Out:
# ['周一', '周二', '周三', '周四', '周五', '周六', '周日']

# %%
print(Faker.clock)
# Out:
# ['12a', '1a', '2a', '3a', '4a', '5a', '6a', '7a', '8a', '9a', '10a', '11a', '12p', '1p', '2p', '3p', '4p', '5p', '6p', '7p', '8p', '9p', '10p', '11p']

# %%
# 0-50 的随机数+列表推导式

# 两层的列表推导式
value = [[i, j, random.randint(0, 50)] for i in range(24) for j in range(7)]

heatmap = (
    HeatMap()
    .add_xaxis(Faker.clock)
    .add_yaxis("热力图", Faker.week, value)
    .set_global_opts(
        title_opts=opts.TitleOpts(title="HeatMap-热力图"),
        visualmap_opts=opts.VisualMapOpts(),
    )
)

heatmap.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1bf41233b7734b3b967dc5456854131f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1bf41233b7734b3b967dc5456854131f = echarts.init(
#                     document.getElementById('1bf41233b7734b3b967dc5456854131f'), 'white', {renderer: 'canvas'});
#                 var option_1bf41233b7734b3b967dc5456854131f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u70ed\u529b\u56fe",
#             "data": [
#                 [
#                     0,
#                     0,
#                     22
#                 ],
#                 [
#                     0,
#                     1,
#                     31
#                 ],
#                 [
#                     0,
#                     2,
#                     37
#                 ],
#                 [
#                     0,
#                     3,
#                     0
#                 ],
#                 [
#                     0,
#                     4,
#                     3
#                 ],
#                 [
#                     0,
#                     5,
#                     33
#                 ],
#                 [
#                     0,
#                     6,
#                     37
#                 ],
#                 [
#                     1,
#                     0,
#                     18
#                 ],
#                 [
#                     1,
#                     1,
#                     37
#                 ],
#                 [
#                     1,
#                     2,
#                     34
#                 ],
#                 [
#                     1,
#                     3,
#                     27
#                 ],
#                 [
#                     1,
#                     4,
#                     21
#                 ],
#                 [
#                     1,
#                     5,
#                     14
#                 ],
#                 [
#                     1,
#                     6,
#                     45
#                 ],
#                 [
#                     2,
#                     0,
#                     20
#                 ],
#                 [
#                     2,
#                     1,
#                     24
#                 ],
#                 [
#                     2,
#                     2,
#                     20
#                 ],
#                 [
#                     2,
#                     3,
#                     29
#                 ],
#                 [
#                     2,
#                     4,
#                     2
#                 ],
#                 [
#                     2,
#                     5,
#                     3
#                 ],
#                 [
#                     2,
#                     6,
#                     27
#                 ],
#                 [
#                     3,
#                     0,
#                     41
#                 ],
#                 [
#                     3,
#                     1,
#                     16
#                 ],
#                 [
#                     3,
#                     2,
#                     47
#                 ],
#                 [
#                     3,
#                     3,
#                     8
#                 ],
#                 [
#                     3,
#                     4,
#                     24
#                 ],
#                 [
#                     3,
#                     5,
#                     36
#                 ],
#                 [
#                     3,
#                     6,
#                     1
#                 ],
#                 [
#                     4,
#                     0,
#                     2
#                 ],
#                 [
#                     4,
#                     1,
#                     5
#                 ],
#                 [
#                     4,
#                     2,
#                     25
#                 ],
#                 [
#                     4,
#                     3,
#                     33
#                 ],
#                 [
#                     4,
#                     4,
#                     22
#                 ],
#                 [
#                     4,
#                     5,
#                     37
#                 ],
#                 [
#                     4,
#                     6,
#                     6
#                 ],
#                 [
#                     5,
#                     0,
#                     31
#                 ],
#                 [
#                     5,
#                     1,
#                     28
#                 ],
#                 [
#                     5,
#                     2,
#                     37
#                 ],
#                 [
#                     5,
#                     3,
#                     15
#                 ],
#                 [
#                     5,
#                     4,
#                     8
#                 ],
#                 [
#                     5,
#                     5,
#                     40
#                 ],
#                 [
#                     5,
#                     6,
#                     35
#                 ],
#                 [
#                     6,
#                     0,
#                     46
#                 ],
#                 [
#                     6,
#                     1,
#                     43
#                 ],
#                 [
#                     6,
#                     2,
#                     3
#                 ],
#                 [
#                     6,
#                     3,
#                     35
#                 ],
#                 [
#                     6,
#                     4,
#                     5
#                 ],
#                 [
#                     6,
#                     5,
#                     42
#                 ],
#                 [
#                     6,
#                     6,
#                     13
#                 ],
#                 [
#                     7,
#                     0,
#                     23
#                 ],
#                 [
#                     7,
#                     1,
#                     17
#                 ],
#                 [
#                     7,
#                     2,
#                     0
#                 ],
#                 [
#                     7,
#                     3,
#                     47
#                 ],
#                 [
#                     7,
#                     4,
#                     25
#                 ],
#                 [
#                     7,
#                     5,
#                     30
#                 ],
#                 [
#                     7,
#                     6,
#                     41
#                 ],
#                 [
#                     8,
#                     0,
#                     42
#                 ],
#                 [
#                     8,
#                     1,
#                     16
#                 ],
#                 [
#                     8,
#                     2,
#                     35
#                 ],
#                 [
#                     8,
#                     3,
#                     43
#                 ],
#                 [
#                     8,
#                     4,
#                     44
#                 ],
#                 [
#                     8,
#                     5,
#                     3
#                 ],
#                 [

# %% [markdown]
# ### 漏斗图

# %%
# 假设某个网站上商品的用户操作行为数据

data = {'操作':["访问","浏览","点击商品","加入购物车","点击支付","支付成功"],
        '人数':[1000, 800, 600, 300, 240, 80]
       }

df1 = pd.DataFrame(data)
df1
# Out:
#       操作    人数
# 0     访问  1000
# 1     浏览   800
# 2   点击商品   600
# 3  加入购物车   300
# 4   点击支付   240
# 5   支付成功    80

# %%
funnel = (
    Funnel()
    .add("商城漏斗", [list(z) for z in zip(df1['操作'].tolist(), df1['人数'].tolist())])
    .set_global_opts(title_opts=opts.TitleOpts(title="商城用户漏斗分析"))
)
    
funnel.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4320a9160f994c2aba5383f25d32c064" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4320a9160f994c2aba5383f25d32c064 = echarts.init(
#                     document.getElementById('4320a9160f994c2aba5383f25d32c064'), 'white', {renderer: 'canvas'});
#                 var option_4320a9160f994c2aba5383f25d32c064 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u57ce\u6f0f\u6597",
#             "data": [
#                 {
#                     "name": "\u8bbf\u95ee",
#                     "value": 1000
#                 },
#                 {
#                     "name": "\u6d4f\u89c8",
#                     "value": 800
#                 },
#                 {
#                     "name": "\u70b9\u51fb\u5546\u54c1",
#                     "value": 600
#                 },
#                 {
#                     "name": "\u52a0\u5165\u8d2d\u7269\u8f66",
#                     "value": 300
#                 },
#                 {
#                     "name": "\u70b9\u51fb\u652f\u4ed8",
#                     "value": 240
#                 },
#                 {
#                     "name": "\u652f\u4ed8\u6210\u529f",
#                     "value": 80
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6d4f\u89c8",
#                 "\u52a0\u5165\u8d2d\u7269\u8f66",
#                 "\u652f\u4ed8\u6210\u529f",
#                 "\u70b9\u51fb\u5546\u54c1",
#                 "\u8bbf\u95ee",
#                 "\u70b9\u51fb\u652f\u4ed8"
#             ],
#             "selected": {
#                 "\u8bbf\u95ee": true,
#                 "\u6d4f\u89c8": true,
#                 "\u70b9\u51fb\u5546\u54c1": true,
#                 "\u52a0\u5165\u8d2d\u7269\u8f66": true,
#                 "\u70b9\u51fb\u652f\u4ed8": true,
#                 "\u652f\u4ed8\u6210\u529f": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5546\u57ce\u7528\u6237\u6f0f\u6597\u5206\u6790",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_4320a9160f994c2aba5383f25d32c064.setOption(option_4320a9160f994c2aba5383f25d32c064);
#         });
#     </script>

# %%
funnel = (
    Funnel()
    .add("商品", [list(z) for z in zip(Faker.choose(), Faker.values())])
    .set_global_opts(title_opts=opts.TitleOpts(title="Funnel-漏斗图"))
)

funnel.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0bd3390eb1bd45f0833d1a0b57351ed2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0bd3390eb1bd45f0833d1a0b57351ed2 = echarts.init(
#                     document.getElementById('0bd3390eb1bd45f0833d1a0b57351ed2'), 'white', {renderer: 'canvas'});
#                 var option_0bd3390eb1bd45f0833d1a0b57351ed2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 115
#                 },
#                 {
#                     "name": "\u6bdb\u8863",
#                     "value": 24
#                 },
#                 {
#                     "name": "\u9886\u5e26",
#                     "value": 96
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 69
#                 },
#                 {
#                     "name": "\u98ce\u8863",
#                     "value": 105
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 62
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u889c\u5b50",
#                 "\u9886\u5e26",
#                 "\u6bdb\u8863",
#                 "\u886c\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u98ce\u8863"
#             ],
#             "selected": {
#                 "\u886c\u886b": true,
#                 "\u6bdb\u8863": true,
#                 "\u9886\u5e26": true,
#                 "\u88e4\u5b50": true,
#                 "\u98ce\u8863": true,
#                 "\u9ad8\u8ddf\u978b": true,
#                 "\u889c\u5b50": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Funnel-\u6f0f\u6597\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_0bd3390eb1bd45f0833d1a0b57351ed2.setOption(option_0bd3390eb1bd45f0833d1a0b57351ed2);
#         });
#     </script>

# %% [markdown]
# ### 仪表盘

# %%
gauge = (
    Gauge()
    .add("", [("完成率", 80)])
    .set_global_opts(title_opts=opts.TitleOpts(title="Gauge-仪表盘"))
)

gauge.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="bc773a7e26fa4a4996510cef27adec85" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_bc773a7e26fa4a4996510cef27adec85 = echarts.init(
#                     document.getElementById('bc773a7e26fa4a4996510cef27adec85'), 'white', {renderer: 'canvas'});
#                 var option_bc773a7e26fa4a4996510cef27adec85 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "radius": "75%",
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 80
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Gauge-\u4eea\u8868\u76d8",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_bc773a7e26fa4a4996510cef27adec85.setOption(option_bc773a7e26fa4a4996510cef27adec85);
#         });
#     </script>

# %% [markdown]
# ### Page组合

# %%
# 1、柱状图

def barPage() -> Bar: 
    bar = (
        Bar()
        .add_xaxis(df['消费'].tolist())
        .add_yaxis("5大开支",df['数据'].tolist())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-月度开支"),
            legend_opts=opts.LegendOpts(is_show=False),)
    )
    return bar

# 2、饼图

def piePage() -> Pie:
    pie = (
        Pie()
        .add("", [list(z) for z in zip(df['消费'].tolist(), df['数据'].tolist())])
        .set_global_opts(title_opts=opts.TitleOpts(title="Pie-月度开支"))
        .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    )
    return pie

# 3、折线图
def linePage() -> Line:
    line = (
        Line()
        .add_xaxis(df['消费'].tolist())
        .add_yaxis("月度开支", df['数据'].tolist())
        .set_global_opts(title_opts=opts.TitleOpts(title="Line-月度开支"))
    )
    return line


# 4、热力图


def heatmapPage() -> HeatMap:
    value = [[i, j, random.randint(0, 50)] for i in range(24) for j in range(7)]
    heatmap = (
        HeatMap()
        .add_xaxis(Faker.clock)
        .add_yaxis("热力图", Faker.week, value)
        .set_global_opts(
            title_opts=opts.TitleOpts(title="HeatMap-热力图"),
            visualmap_opts=opts.VisualMapOpts(),
        )
    )
    return heatmap


# 5、漏斗图
def funnelPage() -> Funnel:
    funnel = (
        Funnel()
        .add("商品", [list(z) for z in zip(Faker.choose(), Faker.values())])
        .set_global_opts(title_opts=opts.TitleOpts(title="Funnel-漏斗图"))
    )
    return funnel


# 6、仪表盘

def gaugePage() -> Gauge:
    gauge = (
        Gauge()
        .add("", [("完成率", 80)])
        .set_global_opts(title_opts=opts.TitleOpts(title="Gauge-仪表盘"))
    )
    return gauge


# 上面是6个图形的代码，下面利用Page进行组合
# !!! 关键步骤
page = (
    Page(layout=Page.DraggablePageLayout)
    .add(
        barPage(),
        piePage(),
        linePage(),
        funnelPage(),
        heatmapPage(),
        gaugePage())
)

page.render("page_demo.html")
# Out:
# '/Users/piqianchao/data-visualization/fourteen-dataVisualization-tool/pyecharts/page_demo.html'

# %%
Page.save_resize_html("page_demo.html",   # 上面的HTML文件名称
                      cfg_file="chart_config.json",  # 保存的json配置文件
                      dest="page_draggable_demo.html")  # 新的文件名称
